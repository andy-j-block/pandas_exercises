# %% [markdown]
# # Getting Financial Data - Pandas Datareader

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import datetime as dt
import numpy as np
import pandas_datareader as pdr

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is).

# %%
date_range = pd.date_range(start='1/1/2015', end=dt.date.today())
len(date_range)
# Out:
# 2157

# %% [markdown]
# ### Step 3. Get an API key for one of the APIs that are supported by Pandas Datareader, preferably for AlphaVantage.
#
# If you do not have an API key for any of the supported APIs, it is easiest to get one for [AlphaVantage](https://www.alphavantage.co/support/#api-key). (Note that the API key is shown directly after the signup. You do *not* receive it via e-mail.)
#
# (For a full list of the APIs that are supported by Pandas Datareader, [see here](https://pydata.github.io/pandas-datareader/readers/index.html). As the APIs are provided by third parties, this list may change.)

# %% [markdown]
# ### Step 4. Use Pandas Datarader to read the daily time series for the Apple stock (ticker symbol AAPL) between 01/01/2015 and today, assign it to df_apple and print it.

# %%
df_apple = pdr.av.time_series.AVTimeSeriesReader(symbols='AAPL', start=date_range[0],end=date_range[-1],api_key='XVI92QWK6G47WZ0I')
df_apple.read()
# Out:
#               open      high      low   close     volume
# 2015-01-02  111.39  111.4400  107.350  109.33   53204626
# 2015-01-05  108.29  108.6500  105.410  106.25   64285491
# 2015-01-06  106.54  107.4300  104.630  106.26   65797116
# 2015-01-07  107.20  108.2000  106.695  107.75   40105934
# 2015-01-08  109.23  112.1500  108.700  111.89   59364547
# ...            ...       ...      ...     ...        ...
# 2020-11-19  117.59  119.0600  116.810  118.64   74112972
# 2020-11-20  118.64  118.7700  117.290  117.34   73604287
# 2020-11-23  117.18  117.6202  113.750  113.85  127959318
# 2020-11-24  113.91  115.8500  112.590  115.17  113226248
# 2020-11-25  115.55  116.7500  115.170  116.03   76499234
#
# [1487 rows x 5 columns]

# %% [markdown]
# ### Step 5. Add a new column "stock" to the dataframe and add the ticker symbol

# %%
df_apple= pd.DataFrame(data=df_apple.read())
df_apple.head()
# Out:
#               open    high      low   close    volume
# 2015-01-02  111.39  111.44  107.350  109.33  53204626
# 2015-01-05  108.29  108.65  105.410  106.25  64285491
# 2015-01-06  106.54  107.43  104.630  106.26  65797116
# 2015-01-07  107.20  108.20  106.695  107.75  40105934
# 2015-01-08  109.23  112.15  108.700  111.89  59364547

# %%
df_apple['stock'] = 'AAPL'
df_apple.head()
# Out:
#               open    high      low   close    volume stock
# 2015-01-02  111.39  111.44  107.350  109.33  53204626  AAPL
# 2015-01-05  108.29  108.65  105.410  106.25  64285491  AAPL
# 2015-01-06  106.54  107.43  104.630  106.26  65797116  AAPL
# 2015-01-07  107.20  108.20  106.695  107.75  40105934  AAPL
# 2015-01-08  109.23  112.15  108.700  111.89  59364547  AAPL

# %% [markdown]
# ### Step 6. Repeat the two previous steps for a few other stocks, always creating a new dataframe: Tesla, IBM and Microsoft. (Ticker symbols TSLA, IBM and MSFT.)

# %%
df_tesla = pdr.av.time_series.AVTimeSeriesReader(symbols='TSLA', start=date_range[0],end=date_range[-1],api_key='XVI92QWK6G47WZ0I')
df_tesla = pd.DataFrame(data=df_tesla.read())

# %%
df_ibm = pdr.av.time_series.AVTimeSeriesReader(symbols='IBM', start=date_range[0],end=date_range[-1],api_key='XVI92QWK6G47WZ0I')
df_ibm = pd.DataFrame(data=df_ibm.read())

# %%
df_microsoft = pdr.av.time_series.AVTimeSeriesReader(symbols='MSFT', start=date_range[0],end=date_range[-1],api_key='XVI92QWK6G47WZ0I')
df_microsoft = pd.DataFrame(data=df_microsoft.read())

# %%
df_tesla['stock'] = 'TSLA'
df_ibm['stock'] = 'IBM'
df_microsoft['stock'] = 'MSFT'

# %% [markdown]
# ### Step 7. Combine the four separate dataFrames into one combined dataFrame df that holds the information for all four stocks

# %%
df = pd.concat([df_apple,df_tesla,df_ibm,df_microsoft])
df
# Out:
#               open     high      low   close    volume stock
# 2015-01-02  111.39  111.440  107.350  109.33  53204626  AAPL
# 2015-01-05  108.29  108.650  105.410  106.25  64285491  AAPL
# 2015-01-06  106.54  107.430  104.630  106.26  65797116  AAPL
# 2015-01-07  107.20  108.200  106.695  107.75  40105934  AAPL
# 2015-01-08  109.23  112.150  108.700  111.89  59364547  AAPL
# ...            ...      ...      ...     ...       ...   ...
# 2020-11-19  211.38  213.030  209.930  212.42  24792746  MSFT
# 2020-11-20  212.20  213.285  210.000  210.39  22843119  MSFT
# 2020-11-23  210.95  212.290  208.160  210.11  25683507  MSFT
# 2020-11-24  209.59  214.250  208.860  213.86  33830438  MSFT
# 2020-11-25  215.11  215.290  212.460  213.87  21012887  MSFT
#
# [5948 rows x 6 columns]

# %% [markdown]
# ### Step 8. Shift the stock column into the index (making it a multi-level index consisting of the ticker symbol and the date).

# %%
df.set_index([df.index,df['stock']],inplace=True)
df.drop('stock',axis=1,inplace=True)
df
# Out:
#                     open     high      low   close    volume
#            stock
# 2015-01-02 AAPL   111.39  111.440  107.350  109.33  53204626
# 2015-01-05 AAPL   108.29  108.650  105.410  106.25  64285491
# 2015-01-06 AAPL   106.54  107.430  104.630  106.26  65797116
# 2015-01-07 AAPL   107.20  108.200  106.695  107.75  40105934
# 2015-01-08 AAPL   109.23  112.150  108.700  111.89  59364547
# ...                  ...      ...      ...     ...       ...
# 2020-11-19 MSFT   211.38  213.030  209.930  212.42  24792746
# 2020-11-20 MSFT   212.20  213.285  210.000  210.39  22843119
# 2020-11-23 MSFT   210.95  212.290  208.160  210.11  25683507
# 2020-11-24 MSFT   209.59  214.250  208.860  213.86  33830438
# 2020-11-25 MSFT   215.11  215.290  212.460  213.87  21012887
#
# [5948 rows x 5 columns]

# %% [markdown]
# ### Step 7. Create a dataFrame called vol, with the volume values.

# %%
vol = pd.DataFrame(df['volume'])
vol
# Out:
#                     volume
#            stock
# 2015-01-02 AAPL   53204626
# 2015-01-05 AAPL   64285491
# 2015-01-06 AAPL   65797116
# 2015-01-07 AAPL   40105934
# 2015-01-08 AAPL   59364547
# ...                    ...
# 2020-11-19 MSFT   24792746
# 2020-11-20 MSFT   22843119
# 2020-11-23 MSFT   25683507
# 2020-11-24 MSFT   33830438
# 2020-11-25 MSFT   21012887
#
# [5948 rows x 1 columns]

# %% [markdown]
# ### Step 8. Aggregate the data of volume to weekly.
# Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
#### finish
vol.resample('W').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d02b6a0b20e9> in <module>
# ----> 1 vol.resample('W').sum()
#
# C:\ProgramData\Anaconda3\envs\pandas_exercises\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8075
#    8076         axis = self._get_axis_number(axis)
# -> 8077         return get_resampler(
#    8078             self,
#    8079             freq=rule,
#
# C:\ProgramData\Anaconda3\envs\pandas_exercises\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1267     """
#    1268     tg = TimeGrouper(**kwds)
# -> 1269     return tg._get_resampler(obj, kind=kind)
#    1270
#    1271
#
# C:\ProgramData\Anaconda3\envs\pandas_exercises\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1432             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1433
# -> 1434         raise TypeError(
#    1435             "Only valid with DatetimeIndex, "
#    1436             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'MultiIndex'

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015
